# %% [markdown]
# # Wrap output cell google colab

# %%
# To wrap text in google colab output
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# # Prepare data

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# %cd /content/drive/MyDrive/revisi_program_pengujian_skripsi

# %%
# !python prepare_data.py

# %% [markdown]
# # **Setup pyrouge**

# %%
# !git clone https://github.com/andersjo/pyrouge.git /content/rouge
# !git clone https://github.com/bheinzerling/pyrouge /content/pyrouge

# %%
# %cd /content/pyrouge
# Out:
# /content/pyrouge

# %%
# !python setup.py install
# !pyrouge_set_rouge_path '/content/rouge/tools/ROUGE-1.5.5'

# %%
# %cd /content/rouge/tools/ROUGE-1.5.5/data

# %%
# !rm "WordNet-2.0.exc.db"
# !perl ./WordNet-2.0-Exceptions/buildExeptionDB.pl ./WordNet-2.0-Exceptions ./smart_common_words.txt ./WordNet-2.0.exc.db

# %%
# !yes ''| cpan -i XML::DOM

# %% [markdown]
# # Test pyrouge

# %%
# !python -m pyrouge.test

# %% [markdown]
# # **Check GPU**

# %%
# !nvidia-smi

# %% [markdown]
# # Connect Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %% [markdown]
# # Install other library

# %%
# !pip install pytorch_lightning==1.4.9
# !pip install transformers
# !pip install wandb

# %% [markdown]
# # Login WandB (optional)

# %%
# !wandb login #use --relogin for login another account

# %% [markdown]
# # Offline WandB (optional)

# %%
# !wandb offline

# %% [markdown]
# # Disable WandB (optional)

# %%
# !wandb disabled

# %% [markdown]
# # Change current working directory

# %%
# %cd /content/drive/MyDrive/revisi_program_pengujian_skripsi

# %% [markdown]
# # **PENGUJIAN SKRIPSI**

# %% [markdown]
# # **START OF TRAINING**

# %% [markdown]
# **Model BERT**
#
#
# *   Indobert-base-uncased
# *   Bert-base-multilingual-uncased

# %% [markdown]
# ## **PENGUJIAN LEARNING RATE DAN DROPOUT**

# %% [markdown]
# ### **IndoBERT**

# %% [markdown]
# #### Learning rate dan Dropout

# %% [markdown]
# ##### 1e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 1e-5 --classifier_dropout 0.1 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 1e-5 --classifier_dropout 0.3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 1e-5 --classifier_dropout 0.5 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ##### 2e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 2e-5 --classifier_dropout 0.1 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 2e-5 --classifier_dropout 0.3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 2e-5 --classifier_dropout 0.5 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ##### 3e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 3e-5 --classifier_dropout 0.1 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 3e-5 --classifier_dropout 0.3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 3e-5 --classifier_dropout 0.5 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ### **Multilingual BERT**

# %% [markdown]
# #### Learning rate dan Dropout

# %% [markdown]
# ##### 1e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 1e-5 --classifier_dropout 0.1 --seed 1 --do_train

# %%
# !python src/eval.py --fold 1 --epochs 4 --saved_name bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.1_8_4

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 1e-5 --classifier_dropout 0.3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 1e-5 --classifier_dropout 0.5 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ##### 2e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 2e-5 --classifier_dropout 0.1 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 2e-5 --classifier_dropout 0.3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 2e-5 --classifier_dropout 0.5 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ##### 3e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 3e-5 --classifier_dropout 0.1 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 3e-5 --classifier_dropout 0.3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --learning_rate 3e-5 --classifier_dropout 0.5 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ## **PENGUJIAN STACKED TRANSFORMER ENCODER**

# %% [markdown]
# ### **IndoBERT**

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --classifier_transformer_num_layers 1 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --classifier_transformer_num_layers 2 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --classifier_transformer_num_layers 3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ### **Multilingual BERT**

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --classifier_transformer_num_layers 1 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --classifier_transformer_num_layers 2 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ####3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --classifier_transformer_num_layers 3 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ## PENGUJIAN NO TOKEN TYPE IDS

# %% [markdown]
# ### IndoBERT

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 1 --do_train --no_use_token_type_ids

# %%
drive.flush_and_unmount()

# %% [markdown]
# ### Multilingual BERT

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 1 --do_train --no_use_token_type_ids

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ## PENGUJIAN FULL FOLD

# %% [markdown]
# ### **Full fold (IndoBERT)**

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 2 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 3 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 4

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 4 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 5 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ---

# %% [markdown]
# ### **Full fold (Multilingual BERT)**

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 1 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 2 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# ####3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 3 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 4

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 4 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# #### 5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --max_epochs 4 --batch_size 8 --seed 5 --do_train

# %%
drive.flush_and_unmount()

# %% [markdown]
# # **END OF TRAINING**

# %% [markdown]
# ---

# %% [markdown]
# # **START OF TESTING**

# %%
# %cd /content/drive/MyDrive/revisi_program_pengujian_skripsi

# %% [markdown]
# # PENGUJIAN AWAL

# %% [markdown]
# # Ekstraktif

# %% [markdown]
# ## Multilingual BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.1_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_2_1e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_3_1e-05_0.1_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_4_1e-05_0.1_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_5_1e-05_0.1_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ## Indo BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.1_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_2_1e-05_0.1_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_3_1e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_4_1e-05_0.1_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_5_1e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# # Abstraktif

# %% [markdown]
# ## Multilingual BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.1_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_2_1e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_3_1e-05_0.1_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_4_1e-05_0.1_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_5_1e-05_0.1_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ## Indo BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.1_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_2_1e-05_0.1_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_3_1e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_4_1e-05_0.1_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_5_1e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# # PENGUJIAN LAIN

# %% [markdown]
# # Ekstraktif

# %% [markdown]
# ## Indo BERT

# %% [markdown]
# ### Learning rate dan Dropout

# %% [markdown]
# #### 1e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.1_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.3_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ---

# %% [markdown]
# #### 2e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_2e-05_0.1_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_2e-05_0.3_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_2e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# #### 3e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.1_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.3_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %%
drive.flush_and_unmount()

# %% [markdown]
# ### Stacked Transformer Encoder

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --classifier_transformer_num_layers 1 --do_test --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_1_1_3e-05_0.5_8_1.bin --ref_summary 0

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --classifier_transformer_num_layers 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# #### 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --classifier_transformer_num_layers 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_3_1_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ### Token Type Ids

# %% [markdown]
# #### No token type ids

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_basic_no-token-type-ids_sent-rep-tokens_transformer_position_2_1_3e-05_0.5_8_1.bin --do_test --no_use_token_type_ids --ref_summary 0

# %% [markdown]
# #### With token type ids

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_basic_use-token-type-ids_sent-rep-tokens_transformer_position_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ## Multilingual BERT

# %% [markdown]
# ### Learning rate dan Dropout

# %% [markdown]
# #### 1e-5

# %% [markdown]
# ##### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.1_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ##### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.3_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ##### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.5_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ---

# %% [markdown]
# #### 2e-5

# %% [markdown]
# ##### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ##### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.3_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ##### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# #### 3e-5

# %% [markdown]
# ##### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_3e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ##### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_3e-05_0.3_8_3.bin --do_test --ref_summary 0

# %% [markdown]
# ##### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ### Stacked Transformer Encoder

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_1_2e-05_0.1_8_2.bin --classifier_transformer_num_layers 1 --do_test --ref_summary 0

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.1_8_2.bin --classifier_transformer_num_layers 2 --do_test --ref_summary 0

# %% [markdown]
# #### 3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_3_1_2e-05_0.1_8_2.bin --classifier_transformer_num_layers 3 --do_test --ref_summary 0

# %% [markdown]
# ### Token Type Ids

# %% [markdown]
# #### No token type ids

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_no-token-type-ids_2_1_2e-05_0.1_8_3.bin --do_test --no_use_token_type_ids --ref_summary 0

# %% [markdown]
# #### With token type ids

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ---

# %% [markdown]
# # Abstraktif

# %% [markdown]
# ## Indo BERT

# %% [markdown]
# ### Learning rate dan Dropout

# %% [markdown]
# #### 1e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.1_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.3_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_1e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ---

# %% [markdown]
# #### 2e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_2e-05_0.1_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_2e-05_0.3_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_2e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# #### 3e-5

# %% [markdown]
# ###### 0.1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.1_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ###### 0.3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.3_8_1.bin --do_test --ref_summary 1

# %%
drive.flush_and_unmount()

# %% [markdown]
# ###### 0.5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Stacked Transformer Encoder

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --classifier_transformer_num_layers 1 --do_test --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_1_1_3e-05_0.5_8_1.bin --ref_summary 1

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --classifier_transformer_num_layers 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# #### 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --classifier_transformer_num_layers 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_3_1_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Token Type Ids

# %% [markdown]
# #### No token type ids

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_basic_no-token-type-ids_sent-rep-tokens_transformer_position_2_1_3e-05_0.5_8_1.bin --do_test --no_use_token_type_ids --ref_summary 1

# %% [markdown]
# #### With token type ids

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_basic_use-token-type-ids_sent-rep-tokens_transformer_position_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ## Multilingual BERT

# %% [markdown]
# ### Learning rate dan Dropout

# %% [markdown]
# #### 1e-5

# %% [markdown]
# ##### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.1_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ##### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.3_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ##### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_1e-05_0.5_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ---

# %% [markdown]
# #### 2e-5

# %% [markdown]
# ##### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ##### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.3_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ##### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# #### 3e-5

# %% [markdown]
# ##### 0.1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_3e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ##### 0.3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_3e-05_0.3_8_3.bin --do_test --ref_summary 1

# %% [markdown]
# ##### 0.5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Stacked Transformer Encoder

# %% [markdown]
# #### 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_1_2e-05_0.1_8_2.bin --classifier_transformer_num_layers 1 --do_test --ref_summary 1

# %% [markdown]
# #### 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.1_8_2.bin --classifier_transformer_num_layers 2 --do_test --ref_summary 1

# %% [markdown]
# #### 3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_3_1_2e-05_0.1_8_2.bin --classifier_transformer_num_layers 3 --do_test --ref_summary 1

# %% [markdown]
# ### Token Type Ids

# %% [markdown]
# #### No token type ids

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_no-token-type-ids_2_1_2e-05_0.1_8_3.bin --do_test --no_use_token_type_ids --ref_summary 1

# %% [markdown]
# #### With token type ids

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_2_1_2e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ---

# %% [markdown]
# # PENGUJIAN AKHIR TERBAIK

# %% [markdown]
# # Ekstraktif

# %% [markdown]
# ## Multilingual BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_1_2e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_2_2e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_3_2e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_4_2e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_5_2e-05_0.1_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ## Indo BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_2_3e-05_0.5_8_2.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_3_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_4_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_5_3e-05_0.5_8_1.bin --do_test --ref_summary 0

# %% [markdown]
# # Abstraktif

# %% [markdown]
# ## Multilingual BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_1_2e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_2_2e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_3_2e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_4_2e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path bert-base-multilingual-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/multilingual_bert_checkpoints/bert-base-multilingual-uncased_use-token-type-ids_1_5_2e-05_0.1_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ## Indo BERT

# %% [markdown]
# ### Fold 1

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 2

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 2 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_2_3e-05_0.5_8_2.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 3

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 3 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_3_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 4

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 4 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_4_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %% [markdown]
# ### Fold 5

# %%
# !python src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 5 --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_5_3e-05_0.5_8_1.bin --do_test --ref_summary 1

# %%
drive.flush_and_unmount()

# %% [markdown]
# # **END OF TESTING**

# %% [markdown]
# ---

# %% [markdown]
# # Confusion Matrix Model Pengujian Terbaik

# %%
# Confusion Matrix Pengujian Terbaik (IndoBERT, learning rate=3e-5, dropout = 0.5, transformer num layer = 2)
# %run src/main.py --model_name_or_path indolem/indobert-base-uncased --data_path ./prepared_data_basic/indo_news_ --seed 1 --do_test --load_checkpoint /content/drive/MyDrive/revisi_program_pengujian_skripsi/indo_bert_checkpoints/indolem-indobert-base-uncased_use-token-type-ids_2_1_3e-05_0.5_8_1.bin
